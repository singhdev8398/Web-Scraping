# %% [markdown]
# 1. go to a website
# 2. search for a respective product
# 3. locate review part
# 4. scrap all the data in local system

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
url='https://www.flipkart.com/search?q='+ "iphone7"

# %%
url
# Out:
# 'https://www.flipkart.com/search?q=iphone7'

# %%
uclient=uReq(url)

# %%
uclient

# %%
flipkarpage=uclient.read()

# %%
flipkarpage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
uclient.close()

# %%
flipkart_html=bs(flipkarpage,'html.parser')

# %%
flipkart_html.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
bigboxes=flipkart_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
for i in bigboxes:
    print(i)
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone7&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,4
# ...

# %%
del bigboxes[0:3]

# %%
box=bigboxes[0]

# %%
box
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBEMK62PN2HU7EE" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-7-black-32-gb/p/itmen6daftcqwzeg?pid=MOBEMK62PN2HU7EE&amp;lid=LSTMOBEMK62PN2HU7EEINTGNU&amp;marketplace=FLIPKART&amp;q=iphone7&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=8c4775f5-57b2-47eb-a21a-6b3976485faa.MOBEMK62PN2HU7EE.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=aehjic0u1s0000001683172778634&amp;qH=c848b7081ba96a14" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 7 (Black, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim1.flixcart.com/image/312/312/k12go7k0/mobile/7/e/e/apple-iphone-7-mn8x2hn-a-original-imafkqcqhzxuvcpd.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="_192laR">Currently unavailable</span></div></div><div class="_3wLduG"><div class="_3
# ...

# %%
box.div.div.div.a['href']
# Out:
# '/apple-iphone-7-black-32-gb/p/itmen6daftcqwzeg?pid=MOBEMK62PN2HU7EE&lid=LSTMOBEMK62PN2HU7EEINTGNU&marketplace=FLIPKART&q=iphone7&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=8c4775f5-57b2-47eb-a21a-6b3976485faa.MOBEMK62PN2HU7EE.SEARCH&ppt=None&ppn=None&ssid=aehjic0u1s0000001683172778634&qH=c848b7081ba96a14'

# %%
productLink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
productLink
# Out:
# 'https://www.flipkart.com/apple-iphone-7-black-32-gb/p/itmen6daftcqwzeg?pid=MOBEMK62PN2HU7EE&lid=LSTMOBEMK62PN2HU7EEINTGNU&marketplace=FLIPKART&q=iphone7&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=8c4775f5-57b2-47eb-a21a-6b3976485faa.MOBEMK62PN2HU7EE.SEARCH&ppt=None&ppn=None&ssid=aehjic0u1s0000001683172778634&qH=c848b7081ba96a14'

# %%
prodRes=requests.get(productLink)

# %%
prodRes
# Out:
# <Response [200]>

# %%
prodRes.encoding='utf-8'

# %%
prod_html=bs(prodRes.text,'html.parser')

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

# %%
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Worth every penny</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Awesome Smartphone for iPhone lover..<br/>I got it during The Big Billion Day Sale..<br/>Camera Quality Awesome<br/>Performance is Superb<br/>Good Display <br/>Beautiful Looking <br/>Battery performs is minus point as per trend it is not as much sufficient but not too bad..<br/>Really love it ?????<br/>Thank you Flipkart..????</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201910/blobio-imr-201910_17fe96da0a9e4f7888585ed49ea67e23.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH
# ...

# %%
len(commentboxes)
# Out:
# 11

# %%
filename=searchString +".csv"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 filename=searchString +".csv"
#
# NameError: name 'searchString' is not defined

# %%
fw=open(filename,'w')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 fw=open(filename,'w')
#
# NameError: name 'filename' is not defined

# %%
header="Product, Customer Name, Rating, Heading, Comment \n"

# %%
name=commentboxes[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Gautam Choudhary'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Gautam Choudhary
# Hemanta Sa
# Ezzazuddin Huseni
# Anish Singh
# suresh b
# Flipkart Customer
# Mayank Chaube
# Shariq Ahmad Beigh
# Jay Nimavat
# chandan kumar panda

# %%
rating=commentboxes[0].div.div.div.div.text
rating
# Out:
# '5'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 4
# 4
# 5
# 5
# 5
# 5

# %%
commenthead=commentboxes[3].find_all("p",{"class":"_2-N8zT"})[0].text
# Out:
# 'Simply awesome'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].find_all("p",{"class":"_2-N8zT"})[0].text)
# Out:
# Worth every penny
# Worth every penny
# Must buy!
# Simply awesome
# Pretty good
# Pretty good
# Perfect product!
# Awesome
# Best in the market!
# Great product

# %%
comtag=commentboxes[0].div.div.find_all("div", {'class':""})[0].text
comtag
# Out:
# 'Awesome Smartphone for iPhone lover..I got it during The Big Billion Day Sale..Camera Quality AwesomePerformance is SuperbGood Display Beautiful Looking Battery performs is minus point as per trend it is not as much sufficient but not too bad..Really love it ?????Thank you Flipkart..????READ MORE'

# %%
for i in range(len(commentboxes)-1):
    print(commentboxes[i].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
    print(commentboxes[i].div.div.div.div.text)
    print(commentboxes[i].find_all("p",{"class":"_2-N8zT"})[0].text)
    print(commentboxes[i].div.div.find_all("div", {'class':""})[0].text)
# Out:
# Gautam Choudhary
# 5
# Worth every penny
# Awesome Smartphone for iPhone lover..I got it during The Big Billion Day Sale..Camera Quality AwesomePerformance is SuperbGood Display Beautiful Looking Battery performs is minus point as per trend it is not as much sufficient but not too bad..Really love it ?????Thank you Flipkart..????READ MORE
# Hemanta Sa
# 5
# Worth every penny
# Thank u Flipkart for your fast delivery. It is awesome and very very nice.I like this very much.READ MORE
# Ezzazuddin Huseni
# 5
# Must buy!
# ...
